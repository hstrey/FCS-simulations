# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import quad,trapz

# %%
# these two function determine the intensity probability function
def f1(y,k,phi0):
    return (np.cos(y*k*phi0)-1)*np.sqrt(-np.log(y))/y
def f2(y,k,phi0):
    return np.sin(y*k*phi0)*np.sqrt(-np.log(y))/y

# %%
k_limit = 200
steps = 20001
k = np.linspace(0,k_limit,steps)
d = k_limit/steps

# %%
def f1_int(k,phi0):
    if hasattr(k,'__iter__'):
        return np.array([quad(f1,0,1,args=(kk,phi0))[0] for kk in k])
    else:
        return quad(f1,0,1,args=(k,phi0))[0]

def f2_int(k,phi0):
    if hasattr(k,'__iter__'):
        return np.array([quad(f2,0,1,args=(kk,phi0))[0] for kk in k])
    else:
        return quad(f2,0,1,args=(k,phi0))[0]

# %%
f1k = f1_int(k,1)
f2k = f2_int(k,1)
plt.plot(k,f1k)
plt.plot(k,f2k)

# %%
prefactor = 0.5*np.pi/np.sqrt(2)
er = np.exp(prefactor*f1k)
ei1 = np.cos(prefactor*f2k)
ei2 = np.sin(prefactor*f2k)
plt.plot(k,er)

# %%
plt.plot(k,ei1)
plt.plot(k,ei2)

# %%
plt.plot(k,er*ei1)
plt.plot(k,er*ei2)
plt.xlim((0,50))
# Out:
# (0, 50)

# %%
# need to find the proper way of doing an fft
freq = np.fft.fftfreq(2*steps-1,d)*2*np.pi
fc1 = er*ei1+1j*er*ei2
fc2 = er*ei1-1j*er*ei2
fc2 = np.conj(fc2[::-1])
fc = np.concatenate((fc1,fc2[1:]))
print(fc.shape)
cf_fft = np.fft.ifft(fc)*np.sqrt(fc.shape[0]/2)
print(cf_fft.shape)
disp = 20000
plt.plot(freq[:disp],np.real(cf_fft[:disp]))
plt.xlim((0,5))
#plt.ylim((1e-2,2))
plt.xlabel("Intensity I")
plt.ylabel("p(I)")
#plt.savefig("pIanalytic5.png",format='png',dpi=300,bbox_inches='tight',facecolor="white",backgroundcolor="white")
# Out:
# (40001,)
# (40001,)
# Text(0,0.5,'p(I)')

# %%
pi = np.real(cf_fft[:steps])
pi[pi<0]=0
print(pi.shape)
# normalization
print(trapz(pi,dx=(freq[1]-freq[0])))
# Out:
# (20001,)
# 1.1076610674402858

# %%
# first moment
print(trapz(pi*freq[:steps],dx=(freq[1]-freq[0])))
# Out:
# 2.143937009850544

# %%
# first moment
print(trapz(pi*(freq[:steps]**2)
            ,dx=(freq[1]-freq[0])))
# Out:
# 4.8732186147485725

# %%
print((np.pi/2)**1.5)
# Out:
# 1.9687012432153024
