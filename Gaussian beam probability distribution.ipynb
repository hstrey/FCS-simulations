# %%
# %matplotlib inline
import numpy as np
import matplotlib.pylab as plt

# %%
t = np.linspace(0,900,2**13+1)
pI_real = np.loadtxt('fIreal.csv',delimiter=',')
pI_imag = np.loadtxt('fIimag.csv',delimiter=',')

# %%
limit = 7000
plt.plot(t[:limit],pI_imag[:limit])
plt.plot(t[:limit],pI_real[:limit])

# %%
limit_upper = 8000
limit_lower = 6800
plt.plot(t[limit_lower:limit_upper],pI_imag[limit_lower:limit_upper])
#plt.plot(t[limit_lower:limit_upper],pI_real[limit_lower:limit_upper])

# %%
limit_upper = 8000
limit_lower = 6800
#plt.plot(t[limit_lower:limit_upper],pI_imag[limit_lower:limit_upper])
plt.plot(t[limit_lower:limit_upper],pI_real[limit_lower:limit_upper])
